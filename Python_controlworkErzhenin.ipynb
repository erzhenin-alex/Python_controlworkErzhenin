# %% [markdown]
# # Контрольная работа

# %% [markdown]
# ## Задача 1. Длина фамилии

# %% [markdown]
# Напишите программу, которая считывает с клавиатуры Вашу фамилию и выводит фразу:
#
# «Моя фамилия [введённая строка] имеет длину [длина введённой строки] символов.».

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# Иванов
# ```
#
# **Вывод:**
#
# ```
# Моя фамилия Иванов имеет длину 6 символов.
#
# ```

# %%
name = str(input())

# %%
# ваш код в этой ячейке
name =  str(input("Введите вашу фамилию: "))
surname_length = len(name)
print(f"Моя фамилия {name} имеет длину {surname_length} символов.")
# Out:
# Моя фамилия Ерженин имеет длину 7 символов.

# %% [markdown]
# ## Задача 2. Умножим строку на число

# %% [markdown]
# Напишите программу, которая принимает на вход три строковые переменные и выводит результат: 123123123456456789
#
# **Подсказка:** воспользуйтесь умножением строки на число.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# 123
# 456
# 789
# ```
#
# **Вывод:**
#
# ```
# 123123123456456789
# ```

# %%
a_1 = str(input("Введите первое значение:"))
a_2 = str(input("Введите второе значение:"))
a_3 = str(input("Введите третье значение:"))

# %%
# ваш код в этой ячейке
a_1 = str(input("Введите первое значение:"))
a_2 = str(input("Введите второе значение:"))
a_3 = str(input("Введите третье значение:"))


result = a_1 * 3 + a_2 * 2 + a_3
print(result)
# Out:
# 123123123456456789

# %% [markdown]
# ## Задача 3. Сокращаем до первых букв

# %% [markdown]
# На вход программе подаются три строки - названия трех городов. Напишите программу, которая выводит первые буквы в их названиях.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# Москва
# Казань
# Санкт-Петербург
# ```
#
# **Вывод:**
#
# ```
# МКС
# ```

# %%
a = input("Введите название первого города: ")
b = input("Введите название второго города: ")
c = input("Введите название третьего города: ")

# %%
# ваш код в этой ячейке
a = input("Введите название первого города: ")
b = input("Введите название второго города: ")
c = input("Введите название третьего города: ")

first_letters = a[0] + b[0] + c[0]
print("Первые буквы в названиях городов:", first_letters)
# Out:
# Первые буквы в названиях городов: МПУ

# %% [markdown]
# ## Задача 4. Обмен половинок

# %% [markdown]
# На вход программе подается строка текста. Напишите программу, которая раздлит ее на две равные части, переставит их местами и выведет на экран.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# Привет, Андрей!
# ```
#
# **Вывод:**
#
# ```
# Андрей!Привет,
# ```

# %%
s = input("Введите текст: ")

# %%
# ваш код в этой ячейке
s = input("Введите текст: ")

# Находим середину строки
mid = len(s) // 2

# Разделяем строку на две части и переставляем их местами
swapped_s = s[mid:] + s[:mid]

print("Результат:", swapped_s)
# Out:
# Результат:  Андрей!Привет,

# %% [markdown]
# ## Задача 5. Таракан

# %% [markdown]
# Убежавший студент из задания 2 позвал на помощь с переписью вещей своего друга, который тараканов просто игнорирует. Необходимо вывести на экран вещи из списка студента, а если среди вещей появится '`таракан`' — на экран его не выводить, но цикл продолжить.
#
# Примечение: необходимо предлагать ввод вещей с клавиатуры.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# учебник
# тетрадь
# грязная кружка
# таракан
# степлер
# носки
# ```
#
# **Вывод:**
#
# ```
# учебник
# тетрадь
# грязная кружка
# степлер
# носки
# ```

# %%
# ваш код в этой ячейке
while True:
    item = input("Введите вещь (для завершения введите 'конец'): ")
    if item == 'конец':
        break
    if 'таракан' in item:
        continue
    print(item)
# Out:
# туфли
# шарф
# колготки
# платок
# носки

# %% [markdown]
# ## Задача 6. Инвентаризация в художественной мастерской

# %% [markdown]
# Владелец художественной мастерской ежегодно делает заказ на приобретение следующих материалов: Кисть,
# Краски,
# Разбавитель,
# Шпатель,
# Холст,
# Палитра.
#
# Помогите ему подсчитать количество приобретенных материалов за 3 года, если дано количество по каждому году.
#
# Результат вывести в формате:
# Количество приобретенных материалов вида `material` за 3 года составило `summa` шт.
#
#
#
# ***Примечание: Решите задачу двумя способами без использования zip и с использованием.***

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# [60, 15, 5, 2, 5, 15]
# [45, 8, 3, 2, 3, 13]
# [10, 8, 3, 2, 0, 10]
#
# ```
#
#
# ```
# Количество приоберетенной посуды вида "Кисть" за 3 года составило 115 шт.
# Количество приоберетенной посуды вида "Краски" за 3 года составило 31 шт.
# Количество приоберетенной посуды вида "Разбавитель" за 3 года составило 11 шт.
# Количество приоберетенной посуды вида "Шпатель" за 3 года составило 6 шт.
# Количество приоберетенной посуды вида "Холст" за 3 года составило 8 шт.
# Количество приоберетенной посуды вида "Палитра" за 3 года составило 38 шт.
# ```

# %%
# ваш код в этой ячейке (без использования zip)
materials = ['Кисть', 'Краски', 'Разбавитель', 'Шпатель', 'Холст', 'Палитра']
years = [
    [60, 15, 5, 2, 5, 15],
    [45, 8, 3, 2, 3, 13],
    [10, 8, 3, 2, 0, 10]
]

for i in range(len(materials)):
    total = years[0][i] + years[1][i] + years[2][i]
    print(f"Количество приобретенных материалов вида '{materials[i]}' за 3 года составило {total} шт.")
# Out:
# Количество приобретенных материалов вида 'Кисть' за 3 года составило 115 шт.
# Количество приобретенных материалов вида 'Краски' за 3 года составило 31 шт.
# Количество приобретенных материалов вида 'Разбавитель' за 3 года составило 11 шт.
# Количество приобретенных материалов вида 'Шпатель' за 3 года составило 6 шт.
# Количество приобретенных материалов вида 'Холст' за 3 года составило 8 шт.
# Количество приобретенных материалов вида 'Палитра' за 3 года составило 38 шт.

# %%
# ваш код в этой ячейке (c использованием zip)

materials = ['Кисть', 'Краски', 'Разбавитель', 'Шпатель', 'Холст', 'Палитра']
years = [
    [60, 15, 5, 2, 5, 15],
    [45, 8, 3, 2, 3, 13],
    [10, 8, 3, 2, 0, 10]
]

for material, counts in zip(materials, zip(*years)):
    total = sum(counts)
    print(f"Количество приобретенных материалов вида '{material}' за 3 года составило {total} шт.")
# Out:
# Количество приобретенных материалов вида 'Кисть' за 3 года составило 115 шт.
# Количество приобретенных материалов вида 'Краски' за 3 года составило 31 шт.
# Количество приобретенных материалов вида 'Разбавитель' за 3 года составило 11 шт.
# Количество приобретенных материалов вида 'Шпатель' за 3 года составило 6 шт.
# Количество приобретенных материалов вида 'Холст' за 3 года составило 8 шт.
# Количество приобретенных материалов вида 'Палитра' за 3 года составило 38 шт.

# %% [markdown]
# ## Задача 6. Сотрудники

# %% [markdown]
# В программе задан пустой словарь workers.
#
# Программа принимает на вход 3 параметра для каждого из сотрудников: имя, должность и зарплату.
#
# Напишите функцию, которая принимает на вход имя, должность и зарплату сотрудника, и добавляет его в словарь по следующему правилу: ключом словаря являются имена работников, а значением — вложенный словарь, содержащий информацию о должности и зарплате.
#
# 1) Вызовите вашу функцию для переданных параметров, а затем выведите полученный словарь на экран.
#
# 2) Задан непустой словарь workers с информацией о сотрудниках предприятия (как в .1). Простая печать словаря при помощи функции print() довольно тяжело читается пользователем. Усовершенствуйте вывод информации из словаря: используя метод .items() и цикл for выведите построчно информацию о каждом рсотрудника
# 3) Представим себе, что Алексей Трегубов (информация о нем есть в словаре) только что прошел аккредитацию на мидл-разработчика.
#
# Программа принимает на вход 2 переменные: строковую — с названием новой позиции сотрудника, и числовую — с новым значением его зарплаты.
#
# Замените позицию и зарплату сотрудника в словаре на переданные в соответствующих переменных значения. Выведите на экран информацию о данном сотруднике, обратившись к словарю по имени сотрудника.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Для п. 1.**
#
# **Ввод:**
#
# ```
# Василий Петрович
# инженер
# 100
# ```
#
# **Вывод:**
#
# ```
# {'Василий Петрович': {'position': 'инженер', 'salary': 100}}
# ```
#
#
# ---
#
#
# **Для п. 2.**
#
# **Ввод:**
#
# ```
# Василий Петрович
# инженер
# 100
# ```
#
# **Вывод:**
#
# ```
# Алексей Трегубов {'должность': 'программист', 'позиция': 'младший', 'зарплата': 120000}
# ```
#
#
# ---
#
#
# **Для п. 3.**
#
# **Ввод:**
#
# ```
# мидл
# 190000
# ```
#
# **Вывод:**
#
# ```
# {'должность': 'программист', 'позиция': 'мидл', 'зарплата': 190000}
# ```

# %%
print("Первый пункт.\n")

# Пустой словарь для заданных параметров
workers_params = {}

def add_worker_params(name, position, salary):
    workers_params[name] = {'должность': position, 'зарплата': salary}
    # Добавляем заданные параметры для нового сотрудника
add_worker_params(input("Введите имя сотрудника: "),
                  input("Введите должность сотрудника: "),
                  int(input("Введите зарплату сотрудника: ")))

def print_workers_params():
    print(workers_params)

# Выводим словарь с заданными параметрами
print_workers_params()

print("Второй пункт.\n")
workers_info = {
    'Алексей Трегубов': {'должность': 'программист', 'позиция': 'младший', 'зарплата': 120000},
    # другие сотрудники
}

def print_workers_info():
    for name, info in workers_info.items():
        print(name)
        for key, value in info.items():
            print(f"{key}: {value}")
        print()

# Выводим словарь с информацией о сотрудниках
print_workers_info()

print("Третий пункт.\n")
def change_worker_position_salary(name, new_position, new_salary):
    workers_info[name]['должность'] = new_position
    workers_info[name]['зарплата'] = new_salary
    print(workers_info[name])

# Изменяем должность и зарплату существующего сотрудника
change_worker_position_salary('Алексей Трегубов',
                              input("Введите новую должность сотрудника: "),
                              int(input("Введите новую зарплату сотрудника: ")))
# Out:
# Первый пункт.
#
# {'ропывавопраыв': {'должность': 'ывпраыовпар', 'зарплата': 76575}}
# Второй пункт.
#
# Алексей Трегубов
# должность: программист
# позиция: младший
# зарплата: 120000
#
# Третий пункт.
#
# {'должность': 'ывсоыворп', 'позиция': 'младший', 'зарплата': 56756}
